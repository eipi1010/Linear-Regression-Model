# %%
#IMPORTS

import linear_regression_class
from importlib import reload
reload(linear_regression_class)
from linear_regression_class import *

# %%
#train and test are read

train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")

# %%
#train and test only includes features that are continuous

train = train.select_dtypes(include=[int,float])
test = test.select_dtypes(include=[int,float])

train.head()
# Out:
#    id  age  alcohol_consumption_per_week  physical_activity_minutes_per_week  \
# 0   0   31                             1                                  45
# 1   1   50                             2                                  73
# 2   2   32                             3                                 158
# 3   3   54                             3                                  77
# 4   4   54                             1                                  55
#
#    diet_score  sleep_hours_per_day  screen_time_hours_per_day   bmi  \
# 0         7.7                  6.8                        6.1  33.4
# 1         5.7                  6.5                        5.8  23.8
# 2         8.5                  7.4                        9.1  24.1
# 3         4.6                  7.0                        9.2  26.6
# 4         5.7                  6.2                        5.1  28.8
#
#    waist_to_hip_ratio  systolic_bp  diastolic_bp  heart_rate  \
# 0                0.93          112            70          62
# 1                0.83          120            77          71
# 2                0.83           95            89          73
# 3                0.83          121            69          74
# 4                0.90          108            60          85
#
#    cholesterol_total  hdl_cholesterol  ldl_cholesterol  triglycerides  \
# 0                199               58              114            102
# 1                199               50              121            124
# 2                188               59              114            108
# 3                182               54               85            123
# 4                206               49              131            124
#
#    family_history_diabetes  hypertension_history  cardiovascular_history  \
# 0                        0                     0                       0
# 1                        0                     0                       0
# 2                        0                     0                       0
# 3                        0                     1                       0
# 4                        0                     1                       0
#
#    diagnosed_diabetes
# 0                 1.0
# 1                 1.0
# 2                 0.0
# 3                 1.0
# 4                 1.0

# %%
#X (age, alcohol_consumption_per_week) and y (diagnosed_diabetes) are defined

X_train = train.loc[:, ['age', 
                        'alcohol_consumption_per_week', 
                        'physical_activity_minutes_per_week',]]

y_train = train['diagnosed_diabetes']

X_test = train.loc[:, ['age',
                       'alcohol_consumption_per_week',
                       'physical_activity_minutes_per_week',]]

# %%
#Training and test the model

weights: np.array = np.array([3,5,6])
bias: float = 2
model = LinearRegression(X_train, y_train, weights, bias, X_test)
model.predict()
# Out:
# array([[ 370],
#        [ 600],
#        [1061],
#        ...,
#        [ 412],
#        [ 579],
#        [ 484]])

# %%
model.get_weights()
# Out:
# 510031.94694714283
# 1.3448884432454046e+17
# 3.546842246069384e+28
# 9.354006261005503e+39
# 2.4669107677591755e+51
# 6
# (array([[-1.05743775e+29],
#         [-4.31610830e+27],
#         [-2.18906401e+29]]),
#  -8.917309631076929e+21)

# %%
print(model.mean_square_error())
prediction = model.submit()
prediction.describe()
# Out:
# 6.50592758474234e+62
# count    7.000000e+05
# mean    -2.289721e+31
# std      1.123881e+31
# min     -1.702950e+32
# 25%     -2.643884e+31
# 50%     -2.078193e+31
# 75%     -1.595669e+31
# max     -3.312049e+30
# dtype: float64

# %%
model.mean_square_error()
# Out:
# 6.50592758474234e+62
